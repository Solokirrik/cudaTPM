# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Графики зависимостей
# plt.plot(x, y)

# %%
x = np.linspace(0, 20, 500)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# * `color`: Цвет линии
#
# * `linestyle`: способ соединения точек: толстая линия, прерывистая, её отсутствие
#
# * `linewidth`: Задаем тонкость линии
#
# * `marker`: Что использовать для обозначения точки(круг, квадрат,треугольник, ничего).
#
# * `markersize`: Очевидно.
#
# * `label`: Название для данного графика в легенде.

# %%
x = np.linspace(0, 20, 10000)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, y1, color='gray', linestyle='-', marker='s', markersize=2, label='sinx')
plt.plot(x, y2, color='green', linestyle='--', marker='^', markersize=5, label='sin(x-pi)')
plt.legend()

# %% [markdown]
# plt.bar(left, height)
#
# * `left`: x координата
#
# * `height`: соответствующая высота столбца

# %%
years = np.arange(2012, 2015)
values = [2, 5, 9]
plt.figure()
plt.bar(years, values)
# Out:
# <Container object of 3 artists>

# %% [markdown]
# * `color`: Цвет столба
#
# * `edgecolor`: Цвет края столба
#
# * `width`: Ширина столбика
#
# * `label`: аналогично как с plot

# %%
years = np.arange(2012, 2015)
category1_values = [2, 5, 9]
category2_values = [7, 6, 3]

plt.figure()

plt.bar(years - 0.2,
        category1_values,
        color='blue',
        edgecolor='none',
        width=0.4,
        align='center',
        label='y1')

plt.bar(years + 0.2,
        category2_values,
        color='orange',
        edgecolor='blue',
        width=0.4,
        align='center',
        label='y2')

plt.xticks(years, [str(year) for year in years])

plt.legend()

# %% [markdown]
# # Круговые графики
#
#
# plt.pie(sizes)
#
# * `sizes`:

# %%
counts = [17, 14]

plt.figure(figsize=(5,5))

plt.pie(counts)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f100a737d90>,
#   <matplotlib.patches.Wedge at 0x7f100a746810>],
#  [<matplotlib.text.Text at 0x7f100a746410>,
#   <matplotlib.text.Text at 0x7f100a746e10>])

# %%
counts = [17, 3]

plt.figure(figsize=(4, 4))

plt.pie(counts,
        colors=['blue', 'orange'],
        labels=['Cats', 'Dogs'],
        startangle=90,
        autopct='%1.1f%%')
;
# Out:
# ''

# %% [markdown]
# # Точечные диаграммы
#
# plt.scatter(x,y)

# %%
x = range(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x, y)

# %% [markdown]
# Многие функции данной библиотеки имеют похожие параметры.

# %%
x = np.arange(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x, y, c='red',
            marker='s',
            edgecolor='blue')

# %% [markdown]
# # Гистограммы
#
# plt.hist(x)
# `x`: Массив для которого мы хотим посмотреть распределение

# %%
column_data = np.random.normal(42, 3, 1000000)

plt.figure()

plt.hist(column_data)
# Out:
# (array([  3.40000000e+01,   1.07800000e+03,   1.83900000e+04,
#           1.21979000e+05,   3.26264000e+05,   3.50538000e+05,
#           1.52905000e+05,   2.69040000e+04,   1.86200000e+03,
#           4.60000000e+01]),
#  array([ 26.87911649,  29.85408333,  32.82905018,  35.80401702,
#          38.77898387,  41.75395071,  44.72891756,  47.7038844 ,
#          50.67885125,  53.65381809,  56.62878494]),
#  <a list of 10 Patch objects>)

# %%
column_data = np.random.normal(42, 3, 10000)

plt.figure()

plt.hist(column_data,color='red',
         bins=50,
         normed=True)
# Out:
# (array([ 0.00043513,  0.00108784,  0.00087027,  0.00087027,  0.00087027,
#          0.00239324,  0.00435135,  0.00609189,  0.00979054,  0.0093554 ,
#          0.01697026,  0.02045134,  0.03241755,  0.03285269,  0.04634187,
#          0.05700268,  0.06722835,  0.08006483,  0.09855806,  0.1103067 ,
#          0.11161211,  0.12466616,  0.12531886,  0.12749453,  0.13358642,
#          0.12684183,  0.12858237,  0.1103067 ,  0.09747022,  0.09551212,
#          0.0815878 ,  0.07070943,  0.05700268,  0.04264322,  0.03872701,
#          0.02850134,  0.02414999,  0.01544729,  0.01087837,  0.00957297,
#          0.00652702,  0.00435135,  0.00152297,  0.00108784,  0.00108784,
#          0.0006527 ,  0.0006527 ,  0.00021757,  0.00021757,  0.00043513]),
#  array([ 31.00903725,  31.4686648 ,  31.92829234,  32.38791989,
#          32.84754744,  33.30717499,  33.76680254,  34.22643009,
#          34.68605763,  35.14568518,  35.60531273,  36.06494028,
#          36.52456783,  36.98419538,  37.44382292,  37.90345047,
#          38.36307802,  38.82270557,  39.28233312,  39.74196067,
#          40.20158821,  40.66121576,  41.12084331,  41.58047086,
#          42.04009841,  42.49972596,  42.9593535 ,  43.41898105,
#          43.8786086 ,  44.33823615,  44.7978637 ,  45.25749125,
#          45.71711879,  46.17674634,  46.63637389,  47.09600144,
#          47.55562899,  48.01525654,  48.47488408,  48.93451163,
#          49.39413918,  49.85376673,  50.31339428,  50.77302183,
#          51.23264937,  51.69227692,  52.15190447,  52.61153202,
#          53.07115957,  53.53078712,  53.99041466]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# # Подграфики
#
# Позволяет вам строить несколько отдельных графиков на одном изображении.
#
# subplot(nrows, ncols, plot_number)
#
# * `nrows`: Количество графиков в ряд по вертикали
#
# * `ncols`: Количество графиков в ряд по горизонтали
#
# * `plot_number`: Расположение графика на изображении, отсчет начинается с 1.

# %%
plt.figure()

for i in range(1, 7):
    plt.subplot(3, 2, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# %% [markdown]
# # Зачем это нужно?

# %%
years = np.arange(2010, 2016)

plt.figure()

for category_num in range(1, 17):
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

plt.ylim(10, 18)
plt.xticks(years, [str(year) for year in years])
# Out:
# ([<matplotlib.axis.XTick at 0x7f1009ff5250>,
#   <matplotlib.axis.XTick at 0x7f1009ff5c90>,
#   <matplotlib.axis.XTick at 0x7f1009fa5810>,
#   <matplotlib.axis.XTick at 0x7f1009f31410>,
#   <matplotlib.axis.XTick at 0x7f1009f31b50>,
#   <matplotlib.axis.XTick at 0x7f1009f3a2d0>],
#  <a list of 6 Text xticklabel objects>)

# %%
years = np.arange(2010, 2016)

plt.figure(figsize=(10, 10))

for category_num in range(1, 17):
    plt.subplot(4, 4, category_num)
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)
    plt.ylim(10, 18)
    plt.xticks(years, [str(year) for year in years])
    plt.title('Number {}'.format(category_num))
    
plt.tight_layout()
